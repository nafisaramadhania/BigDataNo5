# %%
pip install -U mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 1.8 MB/s eta 0:00:00
# Collecting scipy>=1.2.1
#   Downloading scipy-1.14.1-cp311-cp311-win_amd64.whl (44.8 MB)
#      ---------------------------------------- 44.8/44.8 MB 2.7 MB/s eta 0:00:00
# Collecting numpy>=1.16.2
#   Downloading numpy-2.2.0-cp311-cp311-win_amd64.whl (12.9 MB)
#      ---------------------------------------- 12.9/12.9 MB 1.9 MB/s eta 0:00:00
# Collecting pandas>=0.24.2
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# Collecting scikit-learn>=1.3.1
#   Downloading scikit_learn-1.6.0-cp311-cp311-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 2.4 MB/s eta 0:00:00
# Collecting matplotlib>=3.0.0
#   Downloading matplotlib-3.9.3-cp311-cp311-win_amd64.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 3.6 MB/s eta 0:00:00
# Collecting joblib>=0.13.2
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
#      -------------------------------------- 219.8/219.8 kB 4.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.3-cp311-cp311-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 3.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp311-cp311-win_amd64.whl (56 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\downloads\online retail\bd5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Collecting pillow>=8
#   Downloading pillow-11.0.0-cp311-cp311-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 3.6 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\downloads\online retail\bd5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.5 in c:\users\asus\downloads\online retail\bd5\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Installing collected packages: pytz, tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, mlxtend
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.3 mlxtend-0.23.3 numpy-2.2.0 pandas-2.2.3 pillow-11.0.0 pyparsing-3.2.0 pytz-2024.2 scikit-learn-1.6.0 scipy-1.14.1 threadpoolctl-3.5.0 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv(r'C:\Users\ASUS\Downloads\Online Retail\Online Retail.csv')

data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [541909 rows x 8 columns]

# %%
# Preprocessing
basket = data.groupby(['InvoiceNo', 'StockCode']).size().unstack(fill_value=0)
basket = basket > 0 

# Apriori
minsupp = 0.01
frequent_itemsets = apriori(basket, min_support=minsupp, use_colnames=True)

# Association Rules
minconf = 0.4 
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=minconf, num_itemsets=len(frequent_itemsets))

# Results
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#         antecedents     consequents   support  confidence       lift
# 0           (20711)         (20712)  0.011158    0.543233  16.135019
# 1           (20711)         (21931)  0.011506    0.560150  12.079846
# 2           (20711)         (22386)  0.010888    0.530075  11.152679
# 3           (20711)         (22411)  0.010270    0.500000  10.909857
# 4           (20711)        (85099B)  0.013436    0.654135   7.935412
# ..              ...             ...       ...         ...        ...
# 564  (22699, 22698)  (22697, 22423)  0.011699    0.493485  24.674267
# 565  (22699, 22423)  (22697, 22698)  0.011699    0.564246  22.692495
# 566  (22697, 22698)  (22699, 22423)  0.011699    0.470497  22.692495
# 567  (22697, 22423)  (22699, 22698)  0.011699    0.584942  24.674267
# 568  (22698, 22423)  (22699, 22697)  0.011699    0.753731  24.900053
#
# [569 rows x 5 columns]

# %%
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].to_csv('rules_output.csv', index=False)

print("Data berhasil disimpan ke file 'rules_output.csv'")
# Out:
# Data berhasil disimpan ke file 'rules_output.csv'
